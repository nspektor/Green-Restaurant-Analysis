# %%
# Combine reviews with businesses
import pandas as pd

yelp_reviews = pd.read_csv('../data/original_sources/YelpReview.csv', header=0)
yelp_businesses = pd.read_csv('../data/clean_yelp_restaurants.csv', header=0)

# %%
yelp_businesses.head(2)
# Out:
#    Unnamed: 0             business_id  \
# 0           1  QXAEGFB4oINsVuTFxEYKFQ
# 1           2  gnKjwL_1w79qoiV3IC_xQQ
#
#                                           categories  \
# 0  SPECIALTY FOOD  RESTAURANTS  DIM SUM  IMPORTED...
# 1                  SUSHI BARS  RESTAURANTS  JAPANESE
#
#                           name  review_count  stars  \
# 0   EMERALD CHINESE RESTAURANT           128    2.5
# 1  MUSASHI JAPANESE RESTAURANT           170    4.0
#
#                      address         city state postal_code   latitude  \
# 0       30 EGLINTON AVENUE W  MISSISSAUGA    ON     L5R 3E7  43.605499
# 1  10110 JOHNSTON RD, STE 15    CHARLOTTE    NC       28210  35.092564
#
#    longitude
# 0 -79.652289
# 1 -80.859132

# %%
# Yelp Business and Review Data
yelp_businesses = yelp_businesses.drop_duplicates(subset=['business_id'])
yelp_businesses['categories'] = yelp_businesses['categories'].str.replace(',', ' ')

# %%
yelp_reviews = yelp_reviews[['business_id', 'text']]
yelp_reviews['review_text'] = yelp_reviews['text'].str.replace(',', ' ').replace('[', '').replace(']', '')

# %%
yelp_reviews = yelp_reviews.groupby('business_id')['review_text'].apply(list).to_frame().reset_index()
yelp_reviews.head(2)
# Out:
#               business_id                                        review_text
# 0  --1UhMGODdWsrMastO9DZw  [If you are looking for authentic Mexican stre...
# 1  --6MefnULPED_I942VcFNA  [They have the best Chinese BBQ Pork (Char Siu...

# %%
# merge restaurants with their reviews
restaurants_and_reviews = yelp_businesses.merge(yelp_reviews, left_on='business_id', right_on='business_id',
                                                how='inner', suffixes=['_biz', '_test'])
restaurants_and_reviews.head(5)
# Out:
#    Unnamed: 0             business_id  \
# 0           1  QXAEGFB4oINsVuTFxEYKFQ
# 1           2  gnKjwL_1w79qoiV3IC_xQQ
# 2          11  1Dfx3zM-rW4n-31KeC8sJg
# 3          12  5t3KVdMnFgAYmSl1wYLhmA
# 4          13  fweCYi8FmbJXHCqLnwuk8w
#
#                                           categories  \
# 0  SPECIALTY FOOD  RESTAURANTS  DIM SUM  IMPORTED...
# 1                  SUSHI BARS  RESTAURANTS  JAPANESE
# 2  RESTAURANTS  BREAKFAST & BRUNCH  MEXICAN  TACO...
# 3  BARS  NIGHTLIFE  PUBS  BARBERS  BEAUTY & SPAS ...
# 4         ITALIAN  RESTAURANTS  PIZZA  CHICKEN WINGS
#
#                           name  review_count  stars  \
# 0   EMERALD CHINESE RESTAURANT           128    2.5
# 1  MUSASHI JAPANESE RESTAURANT           170    4.0
# 2                    TACO BELL            18    3.0
# 3  THE KILTED BUFFALO LANGTREE             9    3.5
# 4                MARCO'S PIZZA            16    4.0
#
#                      address                city state postal_code   latitude  \
# 0       30 EGLINTON AVENUE W         MISSISSAUGA    ON     L5R 3E7  43.605499
# 1  10110 JOHNSTON RD, STE 15           CHARLOTTE    NC       28210  35.092564
# 2    2450 E INDIAN SCHOOL RD             PHOENIX    AZ       85016  33.495194
# 3   119 LANDINGS DR, STE 101         MOORESVILLE    NC       28117  35.527410
# 4            5981 ANDREWS RD  MENTOR-ON-THE-LAKE    OH       44060  41.708520
#
#     longitude                                        review_text
# 0  -79.652289  [My girlfriend and I went for dinner at Emeral...
# 1  -80.859132  [Husband was craving Chicken Teriyaki & gyoza ...
# 2 -112.028588  [I mean it's Taco Bell  so it is what it is. H...
# 3  -80.868003  [WooHoo  why wasn't this place here when I liv...
# 4  -81.359556  [Hands down  this is the best pizza place in M...

# %%
restaurants_and_reviews.to_csv('../data/big_restaurants_and_reviews.csv', index=False)
small_businesses_and_reviews = restaurants_and_reviews.head(5000)
small_businesses_and_reviews.to_csv('../data/small_restaurants_and_reviews.csv', index=False)
